# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.exponential(scale = 1.0, size = 1000)

# %%
plt.hist(data, bins = 100, edgecolor = 'black')
plt.xlabel("value")
plt.ylabel("frequency")

plt.savefig("session_10_prompt.pdf")
plt.show()
