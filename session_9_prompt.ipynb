# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data =np.random.uniform(0, 1, 1000)

# %%
plt.hist(data, bins=100, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.grid(True)

plt.savefig("session_9_prompt.pdf")
plt.show()
